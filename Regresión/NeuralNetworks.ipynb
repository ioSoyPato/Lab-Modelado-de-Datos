# %% [markdown]
# ___
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://bernardmarr.com/img/What%20is%20an%20Artificial%20Neural%20Networks.jpg" width="350px" height="180px" />
#
#
# # <font color= #8A0829> Laboratorio de Modelado de Datos </font>
# #### <font color= #2E9AFE> `Martes y Viernes (Videoconferencia) de 13:00 - 15:00 hrs`</font>
# - <Strong> Maestra: Sara Eugenia Rodríguez </Strong>
# - <Strong> Alumna: Patricio Villanueva Gio </Strong>
# - <Strong> Año </Strong>: 2023
# - <Strong> Email: </Strong>  <font color="blue"> `cd682324@iteso.mx` </font>
# ___
#
# <p style="text-align:right;"> Imagen recuperada de: https://bernardmarr.com/img/What%20is%20an%20Artificial%20Neural%20Networks.jpg</p>
#
# ### <font color= #2E9AFE> Tema: Redes Neuronales</font>

# %% [markdown]
# **Aplicaciones de la vida real**
#
# - Control del vuelo de aviones
# - Control automotriz
# - Área médica
# - Optimizar el rendimiento del Wi-fi

# %%
from IPython.display import Image
Image(filename='compare_NN.JPG', width=600, height=400)

# %% [markdown]
# Dentro de la caja negra...
#
# **¿Qué es una neurona?**
#
# Es un nombre elegante que le pusieron para referirse a una función en los años de 1940-1950. Se creeía que los nodos eran como neuronas del cerebro.
#
# **¿Qué es una función?**
#
# Es un nombre elegante que pusieron para referirse a algo que toma cosas de entrada, aplica alguna lógica y saca un resultado.
#
# **¿Qué es una red neuronal?**
#
# Es la interconexión de múltiples neuronas (funciones) para resolver un problema complejo que una sola neurona no podría. Dentro de los componentes existen *nodos* y *conexiones*
#
# **Pasos que hace la red neuronal:**
#
# 1. Combinación de las variables de entrada (X). Cada señal recibida tiene una constante w (peso/weight) que permite manipular la importancia de cada variable de entrada.
# 2. Neurona de respuesta. Considerando todas las variables de entrada, la neurona genera una señal de respuesta a través de una función.
#
# **Tipos de capas en la red neuronal**
#
# - Capa de entrada: capa que toma los datos de entrada
# - Capas ocultas: toman las entradas de otra capa y pasan a salida hacia otra capa (son intermediarias entre la entrada y la salida)
# - Capas de salida: capa que hace la predicción
#
# <img style="float: center; margin: 0px 0px 0px 0px;" src="https://www.smartsheet.com/sites/default/files/IC-simplified-artificial-neural-networks-corrected.svg" width="350px" height="180px" />

# %%
from IPython.display import Image
Image(filename='neuron_weights.JPG', width=300, height=200)

# %% [markdown]
# **Modelo matemático de la neurona**
#
# $$\nu = w_{0}+w_{1}x_{1}+w_{2}x_{2}+w_{3}x_{3}+w_{4}x_{4}+w_{5}x_{5}$$
# $$y = \varphi(\nu)$$

# %%
from IPython.display import Image
Image(filename='capa_oculta.JPG', width=300, height=200)

# %% [markdown]
# **Modelo matemático red neuronal**
#
# $$\nu^{1} = w_{0}^{1}+w^{1}$$
# $$y^{1} = \varphi(\nu^{1})$$
# $$\nu^{2} = w_{0}^{2}+w^{2}y_{1}$$
# $$y^{2} = \varphi(\nu^{2})$$

# %%
from IPython.display import Image
Image(filename='capa_oculta2.JPG', width=300, height=200)

# %% [markdown]
# **Modelo matemático usando dos capas oculta**
#
# <font color= #66CC00>$$\nu^{1} = w_{0}^{1}+w^{1}$$</font>
# <font color= #66CC00>$$y^{1} = \varphi(\nu^{1})$$</font>
# <font color= #009900>$$\nu^{2} = w_{0}^{2}+w^{2}y_{1}$$</font>
# <font color= #009900>$$y^{2} = \varphi(\nu^{2})$$</font>
# <font color= #3399FF>$$\nu^{3} = w_{0}^{3}+w^{3}y_{2}$$</font>
# <font color= #3399FF>$$y^{3} = \varphi(\nu^{3})$$</font>
#
#
# **Funciones de activación**
#
# El comportamiento de las neuronas de las redes neuronales es basado en la función en la que la neurona se especializó. Una neurona puede cambiar su respuesta dependiendo de la función de activación $\varphi(*)$ que sea seleccionada
# # Examen
# ## Debe de ser una función de activación lineal en la salida
# Funciones comunes:
# 1. Lineal: $\varphi(\nu)=\nu$
# 2. Sigmoidal: $\varphi(\nu)=\frac{e^{\nu}}{1+e^{\nu}}$
# 3. Tanh: $\varphi(\nu)=\frac{e^{\nu}-e^{-\nu}}{e^{\nu}+e^{-\nu}}=tanh(\nu)$
# 4. Softplus: $\varphi(\nu)=log(1+e^{\nu})$
# 5. RELU: $\varphi(\nu)=max(0,\nu)$
#
# Las funciones de activación suelen ser diferenciables, lo que significa que la derivada de primer orden se puede calcular para un valor de entrada dado. Esto es necesario dado que las redes neuronales generalmente se entrenan utilizando el algoritmo de backpropagation que requiere la derivada del error de predicción para actualizar los pesos del modelo.
#
# **¿Cómo elegir la función de activación para las capas ocultas?**
#
# - Lineal: se recomienda para cuando el problema es sencillo
# - Sigmoidal: típicamente para problemas de clasificación. Sufre del problema de "Gradiente que se desvanece", los gradientes de la salida de la red con respecto a los parámetros se vuelven tan pequeños que la red neuronal da pasos más pequeños hacia los mínimos de la función de costo y finalmente deja de aprender.
# - Tanh: muy similar a la sigmoidal
# - RELU: es la más utilizada para capas ocultas. Es simple de implementar y no es tan susceptible a gradientes que se desvanecen
# - Softmax: no se recomienda mucho usarla ya que el cálculo de gradientes no es tan eficiente
#
# **¿Cómo son las redes neuronales para regresión?**
#
# $$\nu^{1} = w_{0}^{1}+w^{1}$$
# $$y^{1} = \varphi(\nu^{1})$$
# $$\nu^{2} = w_{0}^{2}+w^{2}y_{1}$$
# <font color= #2E9AFE>$$y^{2} = \varphi(\nu^{2})$$</font>
#
# La única diferencia es la última salida. La función de la salida tiene que ser **lineal**
#
# **Backpropagation**
#
# Es el método que usa para ajustar el modelo. Minimiza el error medio cuadrático (MSE), utilizando el gradiente descendente para calcular los parámetros con el orden del último hacia el primero.
#
# **¿Cómo elegir cuántas capas ocultas?**
#
# Se recomienda usar la regla de:
# (# capas ocultas = #entradas + # salidas)
#
# **¿Cómo elegir cuántas neuronas en las capas ocultas?**
#
# Depende....
#
# De forma ideal, el número de neuronas ocultas debe ser mayor al número de entradas (#Neuronas ocultas > # variables de entrada).
#
# Peroooo esta regla tiene varias formas de verse afectada:
#
# 1. Número de datos
# 2. Poder computacional
#
# Si se tienen pocos datos, al aumentar el número de neuronas ocultas, la cantidad de pesos se empieza a ser comparable con las muestras que se tienen, entonces conviene aumentar la cantidad de neuronas ocultas.
#
# Si se tienen muchos datos, esta regla de (#Neuronas ocultas > # variables de entrada) no es fácil por cuestiones computacionales, por lo tanto usamos las siguientes reglas:
#
# - El número de neuronas ocultas debe estar entre el tamaño de la capa de entrada y el tamaño de la capa de salida.
# - El número de neuronas ocultas debe ser 2/3 del tamaño de la capa de entrada, más el tamaño de la capa de salida.
# - El número de neuronas ocultas es la media de las neuronas en las capas de entrada y salida.
#
# **Recomendaciones**
#
# - Se recomienda hacer un pre-procesamiento de los datos - Escalamiento
# - Comúnmente todas las capas ocultas usan la misma función de activación
# - La función de salida generalmente usa diferente función de activación que el de las capas ocultas.
# - En la experiencia, conviene más aumentar el número de neuronas ocultas en lugar de aumentar el número de capas ocultas.
# - Se recomienda no usar muchas capas ocultas

# %%
#pip install scikeras
#pip install keras
#pip install tensorflow

#si por algo no funcionan los comandos anteriores... probar utilizando lo siguiente:
#conda install -c conda-forge keras
#conda install -c conda-forge/label/broken keras
#conda install -c conda-forge/label/cf201901 keras
#conda install -c conda-forge tensorflow=1.14


import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import SGD, Adam
#from tensorflow.keras.optimizers import SGD
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score

# %% [markdown]
# #### Ejemplo de una sola variable (X)

# %%
#Generamos datos
#Generar la X
m = 1000;
X = np.linspace(-1,1,num=m)
X = np.reshape(X,(m,1))

#Generar la Y

#Y = X**2 #Función cuadrática
Y = 2*X**3+2*X**2 
#Y = 4*X*np.sin(10*X)+X*np.exp(X)*np.cos(20*X) 

[m,ne] = np.shape(X)

from sklearn import preprocessing
X = preprocessing.scale(X)
Y = preprocessing.scale(Y)

#graficando los datos
fig = plt.figure()
plt.plot(X,Y, linewidth=3)
plt.grid()

# %%
#Dividimos los datos en test y train
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y,
                                                    test_size=0.2, random_state=42)

# %%
# Diseño del modelo

#Inicializo objeto
model = Sequential()

#Agregar capas

#Agregamos la primera capa de entrada
#capa densa significa que todas las neuronas anteriores van con todas las que siguen
#Elegimos 5 neuronas en esa capa
#input_dim = 1 porque tenemos solo una X. Aquí nos preguntamos: ¿cuántas entradas voy a tener?
model.add(Dense(5, activation='relu', input_dim=1,name='input_layer'))


#si quisiéramos añadir capas ocultas
#model.add(Dense(10, activation='tanh', name='hidden_layer'))

#Agregamos la capa de salida
#la capa de salida tiene que ser lineal
model.add(Dense(1, activation='linear',name='output_layer'))




#gradiente descendente
#épocas = cuántas veces se repite el gradiente descendente para encontrar el mínimo del MSE
#si la funcion de costo J tiene muchos picos, se recomienda disminuir el decaimineto o aumentar la tasa de aprendizaje
#Momentum: Utiliza la ley física del movimiento para atravesar óptimos locales (pequeñas colinas). 
#agrega un impulso que hará que la convergencia sea más rápida

#Hiperparámetros
learning_rate = 0.4
epochs = 200
momentum = 0.8

sgd = SGD(learning_rate=learning_rate, momentum=momentum)


model.compile(loss='mean_squared_error',
              optimizer=sgd, 
             metrics = ['mse'])

# %%
#Ajustamos el modelo
history = model.fit(X_train, y_train, 
                   epochs=epochs, 
                   batch_size=100, 
                   validation_data=(X_test,y_test))
# Out:
# Epoch 1/200
# 8/8 [==============================] - 0s 16ms/step - loss: 1.4036 - mse: 1.4036 - val_loss: 1.7888 - val_mse: 1.7888
# Epoch 2/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.8797 - mse: 0.8797 - val_loss: 0.4099 - val_mse: 0.4099
# Epoch 3/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1347 - mse: 0.1347 - val_loss: 0.1052 - val_mse: 0.1052
# Epoch 4/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.
200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0201 - mse: 0.0201 - val_loss: 0.0194 - val_mse: 0.0194
# Epoch 161/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0203 - mse: 0.0203 - val_loss: 0.0177 - val_mse: 0.0177
# Epoch 162/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0221 - mse: 0.0221 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 163/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0191 - mse: 0.0191 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 164/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0198 - mse: 0.0198 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 165/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0191 - mse: 0.0191 - val_loss: 0.0223 - val_mse: 0.0223
# Epoch 166/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0205 - mse: 0.0205 - val_loss: 0.0237 - val_mse: 0.0237
# Epoch 167/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0207 - mse: 0.0207 - val_loss: 0.0189 - val_mse: 0.0189
# Epoch 168/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0194 - mse: 0.0194 - val_loss: 0.0195 - val_mse: 0.0195
# Epoch 169/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0198 - mse: 0.0198 - val_loss: 0.0186 - val_mse: 0.0186
# Epoch 170/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0241 - mse: 0.0241 - val_loss: 0.0197 - val_mse: 0.0197
# Epoch 171/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0209 - mse: 0.0209 - val_loss: 0.0232 - val_mse: 0.0232
# Epoch 172/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0250 - mse: 0.0250 - val_loss: 0.0280 - val_mse: 0.0280
# Epoch 173/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0311 - mse: 0.0311 - val_loss: 0.0339 - val_mse: 0.0339
# Epoch 174/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0188 - val_mse: 0.0188
# Epoch 175/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0201 - mse: 0.0201 - val_loss: 0.0189 - val_mse: 0.0189
# Epoch 176/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0211 - mse: 0.0211 - val_loss: 0.0257 - val_mse: 0.0257
# Epoch 177/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0202 - mse: 0.0202 - val_loss: 0.0211 - val_mse: 0.0211
# Epoch 178/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0200 - mse: 0.0200 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 179/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0191 - mse: 0.0191 - val_loss: 0.0177 - val_mse: 0.0177
# Epoch 180/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0187 - mse: 0.0187 - val_loss: 0.0178 - val_mse: 0.0178
# Epoch 181/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0205 - mse: 0.0205 - val_loss: 0.0177 - val_mse: 0.0177
# Epoch 182/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0196 - mse: 0.0196 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 183/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0210 - mse: 0.0210 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 184/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0201 - mse: 0.0201 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 185/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0205 - mse: 0.0205 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 186/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0212 - mse: 0.0212 - val_loss: 0.0177 - val_mse: 0.0177
# Epoch 187/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0193 - mse: 0.0193 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 188/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0228 - mse: 0.0228 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 189/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0263 - mse: 0.0263 - val_loss: 0.0238 - val_mse: 0.0238
# Epoch 190/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0338 - mse: 0.0338 - val_loss: 0.0353 - val_mse: 0.0353
# Epoch 191/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0344 - mse: 0.0344 - val_loss: 0.0264 - val_mse: 0.0264
# Epoch 192/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0219 - mse: 0.0219 - val_loss: 0.0190 - val_mse: 0.0190
# Epoch 193/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0191 - mse: 0.0191 - val_loss: 0.0207 - val_mse: 0.0207
# Epoch 194/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0194 - mse: 0.0194 - val_loss: 0.0204 - val_mse: 0.0204
# Epoch 195/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0218 - mse: 0.0218 - val_loss: 0.0206 - val_mse: 0.0206
# Epoch 196/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0202 - mse: 0.0202 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 197/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0195 - mse: 0.0195 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 198/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0189 - val_mse: 0.0189
# Epoch 199/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0206 - mse: 0.0206 - val_loss: 0.0212 - val_mse: 0.0212
# Epoch 200/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0208 - mse: 0.0208 - val_loss: 0.0199 - val_mse: 0.0199

# %%
#Graficar el MSE
fig, ax = plt.subplots(1, 1, figsize=(10,6))
ax.plot(np.sqrt(history.history['mse']), 'r', label='train')
ax.plot(np.sqrt(history.history['val_mse']), 'b' ,label='val')
ax.set_xlabel(r'Epoch', fontsize=20)
ax.set_ylabel(r'MSE', fontsize=20)
ax.legend()
ax.tick_params(labelsize=20)

# %%
#Evaluación del modelo

#Evaluación del modelo en los datos de prueba
score = model.evaluate(X_test,y_test)
print('Test mse:', score[1])
# Out:
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0199 - mse: 0.0199
# Test mse: 0.01988322101533413

# %%
#Predicción  y calcular R2

#Con datos del test
yhat = model.predict(X_test)
R2_score = r2_score(y_test,yhat)
xmin,xmax = min(y_test),max(y_test)
xline = np.linspace(xmin,xmax)
fig = plt.figure(figsize=(10,6))
plt.scatter(y_test,yhat,label='Estimation')
plt.plot(xline,xline,'k--',label='Perfect estimation')
plt.xlabel('Real output', fontsize=20)
plt.ylabel('Estimation output', fontsize=20)
plt.title('Test R^2=%0.4f'%R2_score, fontsize=20)
plt.legend()
plt.grid()
plt.show()
# Out:
# 7/7 [==============================] - 0s 853us/step

# %%
print('R2:', R2_score)
# Out:
# R2: 0.9816136220005686

# %% [markdown]
# #### Ejemplo Multivariable (Más de una variable de entrada X)

# %%
m = 100;
X = np.linspace(-1,1,num=m)
[x1,x2] = np.meshgrid(X,X)
X = np.c_[x1.ravel(),x2.ravel()]
Y = X[:,0]**2+X[:,1]**2 

[m,ne] = np.shape(X)
Y = np.reshape(Y,(m,1))

from sklearn import preprocessing
X = preprocessing.scale(X)
Y = preprocessing.scale(Y)

#from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], Y)

# %%
#Dividimos los datos en test y train
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y,
                                                    test_size=0.2, random_state=42)

# %%
# Diseño del modelo

#Inicializo objeto
model = Sequential()

#Agregar capas

#Agregamos la primera capa de entrada
#input_dim = # de datos de entrada(X)
# 5 = numero de neuronas 
model.add(Dense(5, activation='relu', input_dim=2,name='input_layer')) #tanh
#Si quisiera añadir una capa oculta extra
#model.add(Dense(10, activation='tanh', name='hidden_layer'))
#Agregamos la capa de salida
model.add(Dense(1, activation='linear',name='output_layer'))

#hiperparámetros
epochs = 200
momentum = 0.8

sgd = SGD(learning_rate=learning_rate, momentum=momentum)
model.compile(loss='mean_squared_error',
              optimizer=sgd, 
             metrics = ['mse'])

# %%
#Ajustamos el modelo
history = model.fit(X_train, y_train, 
                   epochs=epochs, 
                   batch_size=100, 
                   validation_data=(X_test,y_test))
# Out:
# Epoch 1/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2582 - mse: 0.2582 - val_loss: 0.1094 - val_mse: 0.1094
# Epoch 2/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0411 - mse: 0.0411 - val_loss: 0.0378 - val_mse: 0.0378
# Epoch 3/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0283 - mse: 0.0283 - val_loss: 0.0240 - val_mse: 0.0240
# Epoch 4/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0296 - mse: 0.0296 - val_loss: 0.0254 - val_mse: 0.0254
# Epoch 5/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0287 - mse: 0.0287 - val_loss: 0.0265 - val_mse: 0.0265
# Epoch 6/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0264 - mse: 0.0264 - val_loss: 0.0319 - val_mse: 0.0319
# Epoch 7/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0272 - mse: 0.0272 - val_loss: 0.0250 - val_mse: 0.0250
# Epoch 8/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0313 - mse: 0.0313 - val_loss: 0.0250 - val_mse: 0.0250
# Epoch 9/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0301 - mse: 0.0301 - val_loss: 0.0239 - val_mse: 0.0239
# Epoch 10/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0341 - mse: 0.0341 - val_loss: 0.0348 - val_mse: 0.0348
# Epoch 11/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0286 - mse: 0.0286 - val_loss: 0.0245 - val_mse: 0.0245
# Epoch 12/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0306 - mse: 0.0306 - val_loss: 0.0519 - val_mse: 0.0519
# Epoch 13/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0271 - mse: 0.0271 - val_loss: 0.0269 - val_mse: 0.0269
# Epoch 14/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0280 - mse: 0.0280 - val_loss: 0.0804 - val_mse: 0.0804
# Epoch 15/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0294 - mse: 0.0294 - val_loss: 0.0239 - val_mse: 0.0239
# Epoch 16/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0273 - mse: 0.0273 - val_loss: 0.0289 - val_mse: 0.0289
# Epoch 17/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0286 - mse: 0.0286 - val_loss: 0.0238 - val_mse: 0.0238
# Epoch 18/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0283 - mse: 0.0283 - val_loss: 0.0325 - val_mse: 0.0325
# Epoch 19/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0283 - mse: 0.0283 - val_loss: 0.0326 - val_mse: 0.0326
# Epoch 20/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.
200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0305 - mse: 0.0305 - val_loss: 0.0368 - val_mse: 0.0368
# Epoch 177/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0274 - mse: 0.0274 - val_loss: 0.0291 - val_mse: 0.0291
# Epoch 178/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0297 - mse: 0.0297 - val_loss: 0.0290 - val_mse: 0.0290
# Epoch 179/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0269 - mse: 0.0269 - val_loss: 0.0288 - val_mse: 0.0288
# Epoch 180/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0282 - mse: 0.0282 - val_loss: 0.0281 - val_mse: 0.0281
# Epoch 181/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0277 - mse: 0.0277 - val_loss: 0.0309 - val_mse: 0.0309
# Epoch 182/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0296 - mse: 0.0296 - val_loss: 0.0250 - val_mse: 0.0250
# Epoch 183/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0256 - mse: 0.0256 - val_loss: 0.0233 - val_mse: 0.0233
# Epoch 184/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0300 - mse: 0.0300 - val_loss: 0.0251 - val_mse: 0.0251
# Epoch 185/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0305 - mse: 0.0305 - val_loss: 0.0310 - val_mse: 0.0310
# Epoch 186/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0286 - mse: 0.0286 - val_loss: 0.0303 - val_mse: 0.0303
# Epoch 187/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0292 - mse: 0.0292 - val_loss: 0.0339 - val_mse: 0.0339
# Epoch 188/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0277 - mse: 0.0277 - val_loss: 0.0268 - val_mse: 0.0268
# Epoch 189/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0301 - mse: 0.0301 - val_loss: 0.0266 - val_mse: 0.0266
# Epoch 190/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0300 - mse: 0.0300 - val_loss: 0.0237 - val_mse: 0.0237
# Epoch 191/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0325 - mse: 0.0325 - val_loss: 0.0338 - val_mse: 0.0338
# Epoch 192/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0290 - mse: 0.0290 - val_loss: 0.0264 - val_mse: 0.0264
# Epoch 193/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0273 - mse: 0.0273 - val_loss: 0.0238 - val_mse: 0.0238
# Epoch 194/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0300 - mse: 0.0300 - val_loss: 0.0269 - val_mse: 0.0269
# Epoch 195/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0306 - mse: 0.0306 - val_loss: 0.0267 - val_mse: 0.0267
# Epoch 196/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0270 - mse: 0.0270 - val_loss: 0.0233 - val_mse: 0.0233
# Epoch 197/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0285 - mse: 0.0285 - val_loss: 0.0251 - val_mse: 0.0251
# Epoch 198/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0262 - mse: 0.0262 - val_loss: 0.0249 - val_mse: 0.0249
# Epoch 199/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0276 - mse: 0.0276 - val_loss: 0.0274 - val_mse: 0.0274
# Epoch 200/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0263 - mse: 0.0263 - val_loss: 0.0291 - val_mse: 0.0291

# %%
#Graficar el MSE
fig, ax = plt.subplots(1, 1, figsize=(10,6))
ax.plot(np.sqrt(history.history['mse']), 'r', label='train')
ax.plot(np.sqrt(history.history['val_mse']), 'b' ,label='val')
ax.set_xlabel(r'Epoch', fontsize=20)
ax.set_ylabel(r'MSE', fontsize=20)
ax.legend()
ax.tick_params(labelsize=20)

# %%
#Evaluación del modelo

#Evaluación del modelo en los datos de prueba
score = model.evaluate(X_test,y_test)
print('Test mse:', score[1])
# Out:
# 63/63 [==============================] - 0s 776us/step - loss: 0.0291 - mse: 0.0291
# Test mse: 0.02907113917171955

# %%
#Predicción  y calcular R2

#Con datos del test
yhat = model.predict(X_test)
R2_score = r2_score(y_test,yhat)
xmin,xmax = min(y_test),max(y_test)
xline = np.linspace(xmin,xmax)
fig = plt.figure(figsize=(10,6))
plt.scatter(y_test,yhat,label='Estimation')
plt.plot(xline,xline,'k--',label='Perfect estimation')
plt.xlabel('Real output', fontsize=20)
plt.ylabel('Estimation output', fontsize=20)
plt.title('Test R^2=%0.4f'%R2_score, fontsize=20)
plt.legend()
plt.grid()
plt.show()
# Out:
# 63/63 [==============================] - 0s 716us/step

# %%
print('R2:', R2_score)
# Out:
# R2: 0.9706209457229468

# %% [markdown]
# #### Ejemplo Cross Validation

# %%
### Cross Validation
from scikeras.wrappers import KerasClassifier, KerasRegressor
from sklearn.model_selection import cross_val_score

# %%
# Crear función que regresa una red neuronal compilada
def create_network():
    
    # Iniciar objeto de red neuronal
    network = Sequential()

    # Añadir una capa de entrada
    network.add(Dense(5, activation='tanh', input_dim=2,name='input_layer')) #Relu

    # Añadir capa oculta
    #network.add(Dense(10, activation='relu')) #tanh

    # Añadir capa de salida
    network.add(Dense(1, activation='linear'))
    
    opt = keras.optimizers.SGD(learning_rate=learning_rate,momentum=momentum)
    
    # Compilar la red neuronal
    network.compile(loss='mean_squared_error', 
                    optimizer=opt, 
                    metrics=['mse']) 
    
    #regresa la red compilada
    return network

# %%
# Hacer el modelo en keras para que pueda ser usado por scikit-learn
neural_network = KerasRegressor(model=create_network, 
                                 epochs=200, 
                                 batch_size=100, 
                                 vaerbose=0)

# %%
# Evaluar la red neuronal usando 4-fold cross-validation
print('MSE:', (-cross_val_score(neural_network, X, Y, cv=4,  scoring='neg_mean_squared_error')).mean())
# Out:
# MSE: 0.5046198019839083

# %%
print('R2:', (cross_val_score(neural_network, X, Y, cv=4,  scoring='r2')).mean())
# Out:
# R2: 0.4754383673917066

# %% [markdown]
# ### Optimización de hiperparámetros
#
# **GridSearch**
#
# ![GridSearch](https://www.yourdatateacher.com/wp-content/uploads/2021/03/image-7.png)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score,mean_squared_error,make_scorer

# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from scikeras.wrappers import KerasRegressor

# Function to create model
def create_model():
    # create model
    model = Sequential()
    model.add(Dense(5, input_shape=(2,), activation='tanh'))
    model.add(Dense(1, activation='linear'))
    return model

# fix random seed for reproducibility
seed = 7
tf.random.set_seed(seed)

# create model
model = KerasRegressor(model=create_model, loss='mean_squared_error', optimizer='SGD', epochs=100, batch_size=10, verbose=0)

# define the grid search parameters
learn_rate = [0.1, 0.05, 0.01]
momentum = [0.8, 0.6, 0.4] # no copiar y pegar, jugar con valores
param_grid = dict(optimizer__learning_rate=learn_rate, optimizer__momentum=momentum)


selection_score = make_scorer(r2_score) #r2
#selection_score = make_scorer(mean_squared_error,greater_is_better=False) #MSE
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=2, scoring=selection_score)
grid_result = grid.fit(X_train, y_train)

# %%
# summarize results
print('Best: %f using %s' % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print('%f (%f) with: %r' % (mean, stdev, param))
# Out:
# Best: 0.999241 using {'optimizer__learning_rate': 0.05, 'optimizer__momentum': 0.6}
# 0.995213 (0.002016) with: {'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.8}
# 0.998353 (0.000800) with: {'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.6}
# 0.999085 (0.000105) with: {'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.4}
# 0.998864 (0.000543) with: {'optimizer__learning_rate': 0.05, 'optimizer__momentum': 0.8}
# 0.999241 (0.000065) with: {'optimizer__learning_rate': 0.05, 'optimizer__momentum': 0.6}
# 0.998991 (0.000220) with: {'optimizer__learning_rate': 0.05, 'optimizer__momentum': 0.4}
# 0.999158 (0.000071) with: {'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.8}
# 0.994095 (0.004544) with: {'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.6}
# 0.991804 (0.006510) with: {'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.4}

# %%
#Diseñar modelo con métricas optimizadas
epochs = 200
learning_rate = 0.05
momentum = 0.4

# Red neuronal
model = Sequential()
model.add(Dense(5,activation='tanh',input_dim=2))
model.add(Dense(1,activation='linear'))

# Optimizer configuration
#gradiente descendente
opt = keras.optimizers.SGD(learning_rate=learning_rate,momentum=momentum,nesterov=True)
model.compile(loss = 'mean_squared_error',
              optimizer=opt,
              metrics=['mse'])

#Ajustar modelo
model_history = model.fit(X_train,y_train,
                    epochs=epochs,
                    batch_size=200,
                    validation_data=(X_test,y_test))

#performance
score = model.evaluate(X_test,y_test)
print('Test loss:', score[0])
print('Test mse:', score[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3476\1593162414.py in <module>
#       5
#       6 # Red neuronal
# ----> 7 model = Sequential()
#       8 model.add(Dense(5,activation='tanh',input_dim=2))
#       9 model.add(Dense(1,activation='linear'))
#
# NameError: name 'Sequential' is not defined

# %%
# Graficar el mse
fig, ax = plt.subplots(1, 1, figsize=(10,6))
ax.plot(np.sqrt(model_history.history['mse']), 'r', label='train')
ax.plot(np.sqrt(model_history.history['val_mse']), 'b' ,label='val')
ax.set_xlabel(r'Epoch', fontsize=20)
ax.set_ylabel(r'MSE', fontsize=20)
ax.legend()
ax.tick_params(labelsize=20)

# %%
#Predicción  y calcular R2
yhat = model.predict(X_test)

R2_score = r2_score(y_test,yhat)

xmin,xmax = min(y_test),max(y_test)
xline = np.linspace(xmin,xmax)
fig = plt.figure(figsize=(10,6))
plt.scatter(y_test,yhat,label='Estimation')
plt.plot(xline,xline,'k--',label='Perfect estimation')
plt.xlabel('Real output', fontsize=20)
plt.ylabel('Estimation output', fontsize=20)
plt.title('Test R^2=%0.4f'%R2_score, fontsize=20)
plt.legend()
plt.grid()
plt.show()
# Out:
# 63/63 [==============================] - 0s 751us/step

# %% [markdown]
# ### Ventajas y desventajas de las redes neuronales
#
# #### Ventajas
#
# - Capacidad de trabajar con información incompleta
# - Si algo llega a fallar en una neurona, se pueden aún obtener resultados - Tolerantes a fallas
# - Tienen la capacidad de aprender por sí mismas y generar resultados que no se limitan a la información que se les dió al principio.
# - Capacidad de procesamiento en paralelo
# - Autoorganización: la capacidad de agrupar y clasificar grandes cantidades de datos hace que las redes neuronales sean especialmente adecuadas para organizar los complicados problemas visuales que plantea el análisis de imágenes
#
# #### Desventajas
#
# - Debido a su naturaleza de "caja negra" se pierde interpretación del modelo
# - Usualmente requieren muchos más datos que los modelos tradicionales
# - Si hay demasiados datos, la red neuronal requiere procesadores con gran poder de procesamiento
# - No hay regla específica para determinar la estructura de la red - Prueba y error
# - Pueden llegar a convertirse muy complejas

# %% [markdown]
# #### Algunas referencias
#
# - https://keras.io/guides/sequential_model/
# - https://keras.io/api/layers/activations/
# - https://keras.io/optimizers/
# - https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=spiral&regDataset=reg-gauss&learningRate=0.03&regularizationRate=0.003&noise=20&networkShape=4&seed=0.82538&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=regression&initZero=false&hideText=false
